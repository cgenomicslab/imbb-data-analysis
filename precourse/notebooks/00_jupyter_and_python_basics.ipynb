# %% [markdown]
# # Notebook 0: Getting Started with Jupyter & Python
#
# This notebook introduces the Jupyter environment and the absolute basics of Python: printing, variables, data types, and arithmetic.
#
# No prior programming experience is assumed. Run each cell with `Shift+Enter` and read the output before moving on.
#
# ---

# %% [markdown]
# ## 1. The Jupyter Notebook
#
# A Jupyter notebook is a document made of **cells**. There are two kinds:
#
# - **Code cells** — contain Python code. Press `Shift+Enter` to run them.
# - **Markdown cells** — contain formatted text (like this one).
#
# The output of a code cell appears directly below it. Try running the cell below.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ### Essential keyboard shortcuts
#
# Jupyter has two modes:
#
# - **Edit mode** (green border): you are typing inside a cell. Press `Escape` to leave.
# - **Command mode** (blue border): you can navigate between cells. Press `Enter` to edit the selected cell.
#
# **Shortcuts in command mode** (press `Escape` first):
#
# | Shortcut | Action |
# |----------|--------|
# | `Shift+Enter` | Run cell and move to next |
# | `Ctrl+Enter` | Run cell and stay |
# | `A` | Insert cell above |
# | `B` | Insert cell below |
# | `DD` | Delete cell (press D twice) |
# | `M` | Convert cell to Markdown |
# | `Y` | Convert cell to Code |
# | `Z` | Undo cell operation |
#
# **Shortcuts in edit mode:**
#
# | Shortcut | Action |
# |----------|--------|
# | `Shift+Enter` | Run cell |
# | `Tab` | Autocomplete |
# | `Ctrl+/` | Comment/uncomment line |

# %% [markdown]
# **Try it:** press `Escape`, then `B` to insert a new cell below this one. Type `print("it works")` and run it with `Shift+Enter`.

# %% [markdown]
# ### A few things to know
#
# - Cells can be run in any order, but it is best to run them **top to bottom**.
# - If something goes wrong and your code gets stuck, use **Kernel → Restart** from the menu.
# - The number in brackets (e.g. `[3]`) next to a code cell shows the order in which cells were executed. A `[*]` means the cell is still running.
# - Lines starting with `#` are **comments** — Python ignores them.

# %%
# This is a comment. Python will ignore it.
print("This line runs.")
# print("This line does not.")
# Out:
# This line runs.

# %% [markdown]
# Jupyter automatically displays the value of the **last expression** in a cell, even without `print()`.

# %%
6 * 7
# Out:
# 42

# %% [markdown]
# ---
#
# ## 2. Variables
#
# A variable is a name that refers to a value. You create it with `=`.

# %%
# Maria Kabouraki inspired
gene_name = "BRCA1"
expression_level = 245.7
sample_count = 50
is_significant = True

print("Gene:", gene_name)
print("Expression:", expression_level)
print("Samples:", sample_count)
print("Significant?", is_significant)
# Out:
# Gene: BRCA1
# Expression: 245.7
# Samples: 50
# Significant? True

# %% [markdown]
# Variable names can contain letters, numbers, and underscores. They cannot start with a number. Names are case-sensitive: `Gene` and `gene` are different.

# %% [markdown]
# **Try it:** create two variables `control` and `treated` with values 120.0 and 360.0, and print their difference.

# %%
# Try it here

# %% [markdown]
# ---
#
# ## 3. Data Types
#
# Every value in Python has a **type**:
#
# - `str` — text (string), written in quotes: `"BRCA1"`
# - `int` — whole number: `50`
# - `float` — decimal number: `245.7`
# - `bool` — logical: `True` or `False`

# %%
print(type("BRCA1"))
print(type(50))
print(type(245.7))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# You can convert between types when it makes sense.

# %%
print(int("42"))     # string to integer
print(float(10))     # integer to float
print(str(3.14))     # number to string
print(int(9.8))      # float to integer (truncates, does not round)
# Out:
# 42
# 10.0
# 3.14
# 9

# %% [markdown]
# **Try it:** what happens if you run `int("hello")`? Try it below to see the error message.

# %%
# Try it here

# %% [markdown]
# ---
#
# ## 4. Arithmetic

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Integer division:", a // b)
print("Remainder:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Integer division: 3
# Remainder: 1
# Power: 1000

# %% [markdown]
# Division (`/`) always returns a float. Integer division (`//`) returns a whole number.
#
# Use `round()` to control decimal places.

# %%
result = 10 / 3
print("Raw:", result)
print("Rounded:", round(result, 2))
# Out:
# Raw: 3.3333333333333335
# Rounded: 3.33

# %% [markdown]
# ### Comparisons
#
# Comparisons return `True` or `False`.

# %%
x = 10

print("x == 10:", x == 10)   # equal to
print("x != 5:",  x != 5)    # not equal to
print("x > 3:",   x > 3)     # greater than
print("x < 3:",   x < 3)     # less than
print("x >= 10:", x >= 10)   # greater than or equal to
# Out:
# x == 10: True
# x != 5: True
# x > 3: True
# x < 3: False
# x >= 10: True

# %% [markdown]
# `=` assigns a value. `==` checks equality. They are different.
#
# ---
#
# ## 5. Strings
#
# Strings are sequences of characters. You can use single or double quotes.

# %%
gene = "BRCA1"
organism = 'Homo sapiens'

# Length
print("Length:", len(gene))

# Concatenation (joining strings)
label = gene + " (" + organism + ")"
print(label)

# Case conversion
print("Upper:", "atcg".upper())
print("Lower:", "ATCG".lower())
# Out:
# Length: 5
# BRCA1 (Homo sapiens)
# Upper: ATCG
# Lower: atcg

# %% [markdown]
# ### Indexing strings
#
# Individual characters can be accessed by position. **Python counts from 0.**

# %%
seq = "ATCGATCG"

print("First:", seq[0])
print("Second:", seq[1])
print("Last:", seq[-1])
print("First three:", seq[0:3])
# Out:
# First: A
# Second: T
# Last: G
# First three: ATC

# %% [markdown]
# ### Useful string methods

# %%
# Split into parts
header = "gene_id;gene_name;chromosome"
parts = header.split(";")
print(parts)

# Join parts back
print(", ".join(parts))

# Replace characters
print("ATCG".replace("T", "U"))

# Strip whitespace from edges
print("  messy data  ".strip())

# Check if a substring exists
print("ATG" in "ATGATCG")

# Count occurrences
print("ATGATGATG".count("ATG"))
# Out:
# ['gene_id', 'gene_name', 'chromosome']
# gene_id, gene_name, chromosome
# AUCG
# messy data
# True
# 3

# %% [markdown]
# **Try it:** given the sequence below, print it in uppercase, print its length, and count how many times `"atg"` appears.

# %%
sequence = "atgatcgatgctagcatgatg"

# Try it here

# %% [markdown]
# ---
#
# **Next:** [Notebook 1 — Lists, Dictionaries & Control Flow](01_collections_and_control_flow.ipynb)
